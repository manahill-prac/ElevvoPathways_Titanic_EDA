# %% [markdown]
# # Titanic EDA
# Exploratory Data Analysis on Titanic dataset.
#
# Dataset should be placed in `data/train.csv`.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset
df = pd.read_csv('data/train.csv')
df.head()
